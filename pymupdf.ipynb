# %%
import fitz 
from unidecode import unidecode
import pandas as pd
import numpy as np

# %%
my_path = 'Sample_PDF_file.pdf'
doc = fitz.open(my_path)

# %%
for page in doc:
    text = page.get_text()
    print(text)
# Out:
# At Glance
# Football, also called association football or soccer, is a game involving two teams of 11 players who try
# to maneuver the ball into the other team's goal without using their hands or arms. The team that scores
# more goals wins. Football is the world's most popular ball game in numbers of participants and
# spectators.
# ABSTRACT
# The game of association football is played in accordance with the Laws of the Game, a set of rules that
# has been in effect since 1863 and maintained by the International Football Association Board (IFAB)
# since 1886.
# The game is played with a football that is 68–70 cm (27–28 in) in circumference. The two teams
# compete to get the ball into the other team's goal (between the posts and under the bar), thereby
# scoring a goal. When the ball is in play, the players mainly use their feet, but may use any other part of
# their body, except for their hands or arms, to control, strike, or pass the ball. Only the goalkeepers may
# use their hands and arms, and only then within the penalty area.
# At glance 1
# The team that has scored more goals at the end of the game is the winner. Depending on the format of
# the competition, an equal number of goals scored may result in a draw being declared, or the game goes
# into extra time or a penalty shootout.
# At glance 2
# Internationally, association football is governed by FIFA. Under FIFA, there are six continental
# confederations: AFC, CAF, CONCACAF, CONMEBOL, OFC and UEFA. National associations (e.g., The FA or
# JFA) are responsible for managing the game in their own countries both professionally and at an
# amateur level and coordinating competitions in accordance with the Laws of the Game.
# Abstract
# The most senior and prestigious international competitions are the men's FIFA World Cup and the FIFA
# Women's World Cup. The men's World Cup is the most-viewed sporting event in the world, surpassing
# the Olympic Games.

# %%
for page in doc:
    output = page.get_text("blocks")
    previous_block_id = 0  # Set a variable to mark the block id
    for block in output:
        if block[6] == 0:  # We only take the text
            if previous_block_id != block[5]:
                # Compare the block number
                print("\n")
            print(block[4])
# Out:
# At Glance
#
#
#
# Football, also called association football or soccer, is a game involving two teams of 11 players who try
# to maneuver the ball into the other team's goal without using their hands or arms. The team that scores
# more goals wins. Football is the world's most popular ball game in numbers of participants and
# spectators.
#
#
#
# ABSTRACT
#
#
#
# The game of association football is played in accordance with the Laws of the Game, a set of rules that
# has been in effect since 1863 and maintained by the International Football Association Board (IFAB)
# since 1886.
#
#
#
# The game is played with a football that is 68–70 cm (27–28 in) in circumference. The two teams
# compete to get the ball into the other team's goal (between the posts and under the bar), thereby
# scoring a goal. When the ball is in play, the players mainly use their feet, but may use any other part of
# their body, except for their hands or arms, to control, strike, or pass the ball. Only the goalkeepers may
# use their hands and arms, and only then within the penalty area.
#
#
#
# At glance 1
#
#
#
# The team that has scored more goals at the end of the game is the winner. Depending on the format of
# the competition, an equal number of goals scored may result in a draw being declared, or the game goes
# into extra time or a penalty shootout.
#
#
#
# At glance 2
#
#
#
# Internationally, association football is governed by FIFA. Under FIFA, there are six continental
# confederations: AFC, CAF, CONCACAF, CONMEBOL, OFC and UEFA. National associations (e.g., The FA or
# JFA) are responsible for managing the game in their own countries both professionally and at an
# amateur level and coordinating competitions in accordance with the Laws of the Game.
#
#
#
# Abstract
#
#
#
# The most senior and prestigious international competitions are the men's FIFA World Cup and the FIFA
# Women's World Cup. The men's World Cup is the most-viewed sporting event in the world, surpassing
# the Olympic Games.

# %%
block_dict = {}
page_num = 1
for page in doc: # Iterate all pages in the document
    file_dict = page.get_text('dict') # Get the page dictionary
    block = file_dict['blocks'] # Get the block information
    block_dict[page_num] = block # Store in block dictionary
    page_num += 1 # Increase the page value by 
output = []

# %%
for page in doc:
    output += page.get_text("blocks")
previous_block_id = 0 # Set a variable to mark the block id
for block in output:
    if block[6] == 0: # We only take the text
        if previous_block_id != block[5]: # Compare the block number
            print("\n")
        plain_text = unidecode(block[4])
        print(plain_text)
# Out:
# At Glance
#
#
#
# Football, also called association football or soccer, is a game involving two teams of 11 players who try
# to maneuver the ball into the other team's goal without using their hands or arms. The team that scores
# more goals wins. Football is the world's most popular ball game in numbers of participants and
# spectators.
#
#
#
# ABSTRACT
#
#
#
# The game of association football is played in accordance with the Laws of the Game, a set of rules that
# has been in effect since 1863 and maintained by the International Football Association Board (IFAB)
# since 1886.
#
#
#
# The game is played with a football that is 68-70 cm (27-28 in) in circumference. The two teams
# compete to get the ball into the other team's goal (between the posts and under the bar), thereby
# scoring a goal. When the ball is in play, the players mainly use their feet, but may use any other part of
# their body, except for their hands or arms, to control, strike, or pass the ball. Only the goalkeepers may
# use their hands and arms, and only then within the penalty area.
#
#
#
# At glance 1
#
#
#
# The team that has scored more goals at the end of the game is the winner. Depending on the format of
# the competition, an equal number of goals scored may result in a draw being declared, or the game goes
# into extra time or a penalty shootout.
#
#
#
# At glance 2
#
#
#
# Internationally, association football is governed by FIFA. Under FIFA, there are six continental
# confederations: AFC, CAF, CONCACAF, CONMEBOL, OFC and UEFA. National associations (e.g., The FA or
# JFA) are responsible for managing the game in their own countries both professionally and at an
# amateur level and coordinating competitions in accordance with the Laws of the Game.
#
#
#
# Abstract
#
#
#
# The most senior and prestigious international competitions are the men's FIFA World Cup and the FIFA
# Women's World Cup. The men's World Cup is the most-viewed sporting event in the world, surpassing
# the Olympic Games.

# %%
block_dict = {}
page_num = 1
for page in doc: # Iterate all pages in the document
    file_dict = page.get_text('dict') # Get the page dictionary
    block = file_dict['blocks'] # Get the block information
    block_dict[page_num] = block # Store in block dictionary
    page_num += 1 # Increase the page value by 1

# %%
import re
spans = pd.DataFrame(columns=['xmin', 'ymin', 'xmax', 'ymax', 'text', 'tag'])
rows = []
for page_num, blocks in block_dict.items():
    for block in blocks:
        if block['type'] == 0:
            for line in block['lines']:
                for span in line['spans']:
                    xmin, ymin, xmax, ymax = list(span['bbox'])
                    font_size = span['size']
                    text = unidecode(span['text'])
                    span_font = span['font']
                    is_upper = False
                    is_bold = False
                    if "bold" in span_font.lower():
                        is_bold = True
                    if re.sub("[\(\[].*?[\)\]]", "", text).isupper():
                        is_upper = True
                    if text.replace(" ","") !=  "":
                        rows.append((xmin, ymin, xmax, ymax, text,                              is_upper, is_bold, span_font, font_size))
                        span_df = pd.DataFrame(rows, columns=['xmin','ymin','xmax','ymax', 'text', 'is_upper','is_bold','span_font', 'font_size'])

# %%
span_df
# Out:
#          xmin        ymin        xmax        ymax  \
# 0   72.099998   74.851234  133.841125   89.276230
# 1   72.099998  100.500023  532.529724  111.700027
# 2   72.099998  114.930016  539.801941  126.130020
# 3   72.099998  129.350006  498.283386  140.550003
# 4   72.099998  143.750031  123.658539  154.950027
# 5   72.099998  167.761261  135.182220  182.186264
# 6   72.099998  193.399994  531.838623  204.599991
# 7   72.099998  207.819977  519.315796  219.019974
# 8   72.099998  222.220001  127.502029  233.419998
# 9   72.099998  244.649994  502.030487  255.849991
# 10  72.099998  259.069977  514.238098  270.269958
# 11  72.099998  273.470001  531.861023  284.669983
# 12  72.099998  287.899994  535.008179  299.099976
# 13  72.099998  302.330017  362.116669  313.529999
# 14  72.099998  325.531250  141.031128  339.956268
# 15  72.099998  351.950012  534.280090  363.149994
# 16  72.099998  366.369995  542.265808  377.569977
# 17  72.099998  380.800018  240.373795  392.000000
# 18  72.099998  404.011230  139.441116  418.436249
# 19  72.099998  429.649994  490.286652  440.849976
# 20  72.099998  444.050018  539.961182  455.250000
# 21  72.099998  458.470001  504.285370  469.669983
# 22  72.099998  472.869995  468.732056  484.069977
# 23  72.099998  496.081238  125.811127  510.506256
# 24  72.099998  521.719971  532.927795  532.919983
# 25  72.099998  536.949951  533.174561  548.149963
# 26  72.099998  551.380005  163.676147  562.580017
#
#                                                  text  is_upper  is_bold  \
# 0                                          At Glance      False     True
# 1   Football, also called association football or ...     False    False
# 2   to maneuver the ball into the other team's goa...     False    False
# 3   more goals wins. Football is the world's most ...     False    False
# 4                                         spectators.     False    False
# 5                                            ABSTRACT      True     True
# 6   The game of association football is played in ...     False    False
# 7   has been in effect since 1863 and maintained b...     False    False
# 8                                       since 1886.       False    False
# 9   The game is played with a football that is 68-...     False    False
# 10  compete to get the ball into the other team's ...     False    False
# 11  scoring a goal. When the ball is in play, the ...     False    False
# 12  their body, except for their hands or arms, to...     False    False
# 13  use their hands and arms, and only then within...     False    False
# 14                                       At glance 1      False     True
# 15  The team that has scored more goals at the end...     False    False
# 16  the competition, an equal number of goals scor...     False    False
# 17             into extra time or a penalty shootout.     False    False
# 18                                       At glance 2      False    False
# 19  Internationally, association football is gover...     False    False
# 20  confederations: AFC, CAF, CONCACAF, CONMEBOL, ...     False    False
# 21  JFA) are responsible for managing the game in ...     False    False
# 22  amateur level and coordinating competitions in...     False    False
# 23                                          Abstract      False     True
# 24  The most senior and prestigious international ...     False    False
# 25  Women's World Cup. The men's World Cup is the ...     False    False
# 26                                 the Olympic Games.     False    False
#
#        span_font  font_size
# 0   Calibri-Bold     14.425
# 1        Calibri     11.200
# 2        Calibri     11.200
# 3        Calibri     11.200
# 4        Calibri     11.200
# 5   Calibri-Bold     14.425
# 6        Calibri     11.200
# 7        Calibri     11.200
# 8        Calibri     11.200
# 9        Calibri     11.200
# 10       Calibri     11.200
# 11       Calibri     11.200
# 12       Calibri     11.200
# 13       Calibri     11.200
# 14  Calibri-Bold     14.425
# 15       Calibri     11.200
# 16       Calibri     11.200
# 17       Calibri     11.200
# 18       Calibri     14.425
# 19       Calibri     11.200
# 20       Calibri     11.200
# 21       Calibri     11.200
# 22       Calibri     11.200
# 23  Calibri-Bold     14.425
# 24       Calibri     11.200
# 25       Calibri     11.200
# 26       Calibri     11.200

# %%
span_scores = []

span_num_occur = {}

special = '[(_:/,#%\=@)]'

for index, span_row in span_df.iterrows():
    score = round(span_row.font_size)

    text = span_row.text

    if not re.search(special, text):
        if span_row.is_bold:

            score +=1 
        if span_row.is_upper:

            score +=1

    span_scores.append(score)


values, counts = np.unique(span_scores, return_counts=True)

# %%
values, counts = np.unique(span_scores, return_counts=True)

style_dict = {}

for value, count in zip(values, counts):

    style_dict[value] = count

sorted(style_dict.items(), key=lambda x: x[1])
# Out:
# [(14, 1), (16, 1), (15, 3), (11, 22)]

# %%
p_size = max(style_dict, key=style_dict.get)

idx = 0

tag = {}

for size in sorted(values, reverse = True):

    idx += 1

    if size == p_size:

        idx = 0

        tag[size] = 'p'

    if size > p_size:

        tag[size] = 'h{0}'.format(idx)

    if size < p_size:

        tag[size] = 's{0}'.format(idx)

# %%
tag
# Out:
# {16: 'h1', 15: 'h2', 14: 'h3', 11: 'p'}

# %%
span_tags = [tag[score] for score in span_scores]

span_df['tag'] = span_tags

# %%
headings_list = []

text_list = []

tmp = []

heading = ''                                                                                                                

for index, span_row in span_df.iterrows():

    text = span_row.text

    tag = span_row.tag

    if 'h' in tag:

        headings_list.append(text)

        text_list.append('\n'.join(tmp))

        tmp = []

        heading = text

    else:

        tmp.append(text)

text_list.append('\n'.join(tmp))

text_list = text_list[1:]

text_df = pd.DataFrame(zip(headings_list, text_list),columns=['heading', 'content'] )

# %%
text_df
# Out:
#         heading                                            content
# 0    At Glance   Football, also called association football or ...
# 1      ABSTRACT  The game of association football is played in ...
# 2  At glance 1   The team that has scored more goals at the end...
# 3  At glance 2   Internationally, association football is gover...
# 4     Abstract   The most senior and prestigious international ...
